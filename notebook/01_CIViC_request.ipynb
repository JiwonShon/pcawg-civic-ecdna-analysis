# %%
import requests
import pandas as pd
import json

# %%
pd.set_option("display.max_columns", None)
current_directory = os.getcwd()
print("Current Directory:", current_directory)
# Out:
# Current Directory: /Users/jiwon/Desktop/research/AI-coscientist/code

# %%
def fetch_civic_v2_final_fixed():
    url = "https://civicdb.org/api/graphql"
    
    # ... on Variant 구문을 사용하여 인터페이스 내 gene 필드에 접근합니다.
    query = """
    {
      evidenceItems(diseaseId: 146, evidenceType: PREDICTIVE, status: ACCEPTED) {
        nodes {
          id
          evidenceLevel
          significance
          molecularProfile {
            name
            variants {
              ... on Variant {
                name
                gene {
                  name
                }
              }
            }
          }
          therapies {
            name
          }
        }
      }
    }
    """
    
    response = requests.post(url, json={'query': query})
    res_json = response.json()

    if 'errors' in res_json:
        print("Detailed Errors:", json.dumps(res_json['errors'], indent=2))
        return None

    nodes = res_json['data']['evidenceItems']['nodes']
    
    extracted = []
    for n in nodes:
        mp = n['molecularProfile']
        # variants 리스트에서 유전자 정보 추출
        gene_name = "N/A"
        variant_name = "N/A"
        
        if mp['variants']:
            v = mp['variants'][0]
            variant_name = v.get('name', 'N/A')
            if 'gene' in v and v['gene']:
                gene_name = v['gene'].get('name', 'N/A')
        
        extracted.append({
            'Gene': gene_name,
            'Variant': variant_name,
            'Molecular_Profile': mp['name'],
            'Drug_Therapy': ", ".join([t['name'] for t in n['therapies']]),
            'Significance': n['significance'],
            'Level': n['evidenceLevel']
        })
    
    df = pd.DataFrame(extracted)
    print(f">>> Successfully fetched {len(df)} records for BRCA.")
    return df

# 실행
df_civic = fetch_civic_v2_final_fixed()
if df_civic is not None:
    print(df_civic.head())
# Out:
# Detailed Errors: [
#   {
#     "message": "Field 'gene' doesn't exist on type 'Variant'",
#     "locations": [
#       {
#         "line": 13,
#         "column": 17
#       }
#     ],
#     "path": [
#       "query",
#       "evidenceItems",
#       "nodes",
#       "molecularProfile",
#       "variants",
#       "... on Variant",
#       "gene"
#     ],
#     "extensions": {
#       "code": "undefinedField",
#       "typeName": "Variant",
#       "fieldName": "gene"
#     }
#   }
# ]

# %%
# CIViC 정기 데이터 릴리즈 URL (Evidence Items)
url = "https://civicdb.org/downloads/nightly/nightly-ClinicalEvidenceSummaries.tsv"

# 데이터 불러오기
df_all = pd.read_csv(url, sep='\t')
print(df_all.shape)

# %%
print(df_all.shape)
df_all.columns
# Out:
# (4765, 25)
# Index(['molecular_profile', 'molecular_profile_id', 'disease', 'doid',
#        'phenotypes', 'therapies', 'therapy_interaction_type', 'evidence_type',
#        'evidence_direction', 'evidence_level', 'significance',
#        'evidence_statement', 'citation_id', 'source_type', 'asco_abstract_id',
#        'citation', 'nct_ids', 'rating', 'evidence_status', 'evidence_id',
#        'variant_origin', 'last_review_date', 'evidence_civic_url',
#        'molecular_profile_civic_url', 'is_flagged'],
#       dtype='object')

# %%
df_all.head()
# Out:
#   molecular_profile  molecular_profile_id                         disease  \
# 0        JAK2 V617F                    64               Lymphoid Leukemia
# 1      PDGFRA D842V                    99  Gastrointestinal Stromal Tumor
# 2       DNMT3A R882                    32          Acute Myeloid Leukemia
# 3        JAK2 V617F                    64        Chronic Myeloid Leukemia
# 4        JAK2 V617F                    64        Chronic Myeloid Leukemia
#
#      doid phenotypes therapies therapy_interaction_type evidence_type  \
# 0  1037.0        NaN       NaN                      NaN    Diagnostic
# 1  9253.0        NaN       NaN                      NaN    Diagnostic
# 2  9119.0        NaN       NaN                      NaN    Diagnostic
# 3  8552.0        NaN       NaN                      NaN    Diagnostic
# 4  8552.0        NaN       NaN                      NaN    Diagnostic
#
#   evidence_direction evidence_level significance  \
# 0           Supports              B     Negative
# 1           Supports              B     Negative
# 2           Supports              B     Positive
# 3           Supports              B     Positive
# 4           Supports              B     Positive
#
#                                   evidence_statement citation_id source_type  \
# 0  JAK2 V617F is not associated with lymphoid leu...    16081687      PubMed
# 1  GIST tumors harboring PDGFRA D842V mutation ar...    15146165      PubMed
# 2  Young AML patients (<60 years old) with DNMT3A...    22490330      PubMed
# 3  JAK2 V617F is associated with myeloid malignan...    16081687      PubMed
# 4  JAK2 V617F is associated with myeloid neoplasm...    16081687      PubMed
#
#    asco_abstract_id              citation nct_ids  rating evidence_status  \
# 0               NaN   Levine et al., 2005     NaN     4.0        accepted
# 1               NaN   Lasota et al., 2004     NaN     3.0        accepted
# 2               NaN  Ribeiro et al., 2012     NaN     3.0        accepted
# 3               NaN   Levine et al., 2005     NaN     4.0        accepted
# 4               NaN   Levine et al., 2005     NaN     4.0        accepted
#
#    evidence_id variant_origin         last_review_date  \
# 0            1        Somatic  2023-01-09 21:46:26 UTC
# 1            2        Somatic  2023-01-09 21:46:27 UTC
# 2            4        Somatic  2023-01-09 21:46:25 UTC
# 3            5        Somatic  2023-01-09 21:46:26 UTC
# 4            6        Somatic  2023-01-09 21:46:26 UTC
#
#                            evidence_civic_url  \
# 0  https://civicdb.org/links/evidence_items/1
# 1  https://civicdb.org/links/evidence_items/2
# 2  https://civicdb.org/links/evidence_items/4
# 3  https://civicdb.org/links/evidence_items/5
# 4  https://civicdb.org/links/evidence_items/6
#
#                        molecular_profile_civic_url  is_flagged
# 0  https://civicdb.org/links/molecular_profiles/64       False
# 1  https://civicdb.org/links/molecular_profiles/99       False
# 2  https://civicdb.org/links/molecular_profiles/32       False
# 3  https://civicdb.org/links/molecular_profiles/64       False
# 4  https://civicdb.org/links/molecular_profiles/64       False

# %%
# df_all.to_csv('../data/civic_Pan_cancer.csv',index=False)

# %%
df_all['disease'].value_counts(dropna=False)
# df_all[df_all['disease']=='Colorectal Cancer']
# Out:
# disease
# Von Hippel-Lindau Disease         626
# Lung Non-small Cell Carcinoma     443
# Colorectal Cancer                 349
# Chronic Myeloid Leukemia          319
# Cancer                            226
#                                  ...
# Renal Wilms' Tumor                  1
# Peritoneal Carcinoma                1
# Malignant Anus Melanoma             1
# Gliosarcoma                         1
# Pancreatic Endocrine Carcinoma      1
# Name: count, Length: 327, dtype: int64

# %%
# BRCA(Breast Cancer) 데이터만 필터링
df_civic = df_all[df_all['disease'] == 'Breast Cancer'].copy()
df_civic.to_csv('../data/civic_breast_cancer.csv',index=False)
print(df_civic.shape)
df_civic.head()
# 필요한 컬럼만 선택 (지원님 데이터와 합치기 위함)
# df_civic = df_civic[['gene', 'variant', 'drugs', 'clinical_significance', 'evidence_level']]
# print(f">>> {len(df_civic)} records loaded from TSV.")
# Out:
# (199, 25)
#         molecular_profile  molecular_profile_id        disease    doid  \
# 191  CCND1 Overexpression                    20  Breast Cancer  1612.0
# 199             AKT1 E17K                     4  Breast Cancer  1612.0
# 209           ERBB2 L755S                    39  Breast Cancer  1612.0
# 210            ESR1 L536Q                    46  Breast Cancer  1612.0
# 211            ESR1 D538G                    47  Breast Cancer  1612.0
#
#     phenotypes             therapies therapy_interaction_type evidence_type  \
# 191        NaN                   NaN                      NaN    Diagnostic
# 199        NaN  Akt Inhibitor MK2206                      NaN    Predictive
# 209        NaN             Lapatinib                      NaN    Predictive
# 210        NaN       Hormone Therapy                      NaN    Predictive
# 211        NaN       Hormone Therapy                      NaN    Predictive
#
#     evidence_direction evidence_level          significance  \
# 191           Supports              B              Positive
# 199   Does Not Support              D  Sensitivity/Response
# 209           Supports              D            Resistance
# 210           Supports              D            Resistance
# 211           Supports              D            Resistance
#
#                                     evidence_statement citation_id  \
# 191  Cyclin D1 overexpression is associated with th...    15961768
# 199  Breast cancer cell lines with the AKT1 E17K mu...    23888070
# 209  The L755S mutation was shown to confer resista...    23220880
# 210  MCF7 cell lines harboring the L536Q mutation i...    24185512
# 211  MCF7 cell lines harboring the D538G mutation i...    24185512
#
#     source_type  asco_abstract_id             citation nct_ids  rating  \
# 191      PubMed               NaN  Arnold et al., 2005     NaN     4.0
# 199      PubMed               NaN  Beaver et al., 2013     NaN     3.0
# 209      PubMed               NaN    Bose et al., 2013     NaN     5.0
# 210      PubMed               NaN     Toy et al., 2013     NaN     3.0
# 211      PubMed               NaN     Toy et al., 2013     NaN     3.0
#
#     evidence_status  evidence_id variant_origin         last_review_date  \
# 191        accepted          221            NaN  2023-01-09 21:46:25 UTC
# 199        accepted          231        Somatic  2023-01-09 21:46:24 UTC
# 209        accepted          241        Somatic  2023-01-09 21:46:26 UTC
# 210        accepted          242        Somatic  2026-01-06 19:23:29 UTC
# 211        accepted          243        Somatic  2023-01-09 21:46:26 UTC
#
#                                evidence_civic_url  \
# 191  https://civicdb.org/links/evidence_items/221
# 199  https://civicdb.org/links/evidence_items/231
# 209  https://civicdb.org/links/evidence_items/241
# 210  https://civicdb.org/links/evidence_items/242
# 211  https://civicdb.org/links/evidence_items/243
#
#                          molecular_profile_civic_url  is_flagged
# 191  https://civicdb.org/links/molecular_profiles/20       False
# 199   https://civicdb.org/links/molecular_profiles/4       False
# 209  https://civicdb.org/links/molecular_profiles/39       False
# 210  https://civicdb.org/links/molecular_profiles/46       False
# 211  https://civicdb.org/links/molecular_profiles/47       False

# %%
df_civic['molecular_profile'].value_counts(dropna=False)
# Out:
# molecular_profile
# FGFR1 Amplification                                                                                                                             17
# PIK3CA Mutation                                                                                                                                  7
# PIK3CA E542K                                                                                                                                     6
# PTEN Loss                                                                                                                                        6
# ERBB2 Amplification                                                                                                                              5
#                                                                                                                                                 ..
# PIK3CA E545K OR PIK3CA E545Q OR PIK3CA E545A OR PIK3CA E545G OR PIK3CA E545V OR PIK3CA E545D OR PIK3CA E545L OR PIK3CA E545R                     1
# PIK3CA E542K OR PIK3CA E542Q OR PIK3CA E542A OR PIK3CA E542D OR PIK3CA E542G OR PIK3CA E542R OR PIK3CA E542V                                     1
# PIK3CA Q546K OR PIK3CA Q546E OR PIK3CA Q546P OR PIK3CA Q546R OR PIK3CA Q546L OR PIK3CA K111E OR PIK3CA K111N OR PIK3CA K111R OR PIK3CA Q546H     1
# AKT2 EXPRESSION                                                                                                                                  1
# NF2 K159fs                                                                                                                                       1
# Name: count, Length: 124, dtype: int64

# %%
df_civic['therapies'].value_counts(dropna=False)
# Out:
# therapies
# NaN                         49
# Neratinib                   10
# Pictilisib                   7
# Trastuzumab                  7
# Tamoxifen                    6
#                             ..
# Elacestrant                  1
# Fulvestrant,Capivasertib     1
# Erdafitinib                  1
# Pemigatinib                  1
# Futibatinib                  1
# Name: count, Length: 78, dtype: int64

# %%
# df_tp53 = df_civic[df_civic["molecular_profile"].astype(str).str.contains("TP53", na=False)]
df_civic[df_civic["molecular_profile"].astype(str).str.contains("TP53", na=False)]
# Out:
#                      molecular_profile  molecular_profile_id        disease  \
# 275                         TP53 R175H                   116  Breast Cancer
# 331                         TP53 R175H                   116  Breast Cancer
# 332                         TP53 R248Q                   117  Breast Cancer
# 333                         TP53 R248Q                   117  Breast Cancer
# 334                         TP53 R248W                   118  Breast Cancer
# 335                      TP53 Mutation                   222  Breast Cancer
# 336                         TP53 R273C                   121  Breast Cancer
# 337                         TP53 R273C                   121  Breast Cancer
# 338                         TP53 R273H                   122  Breast Cancer
# 339                         TP53 R273H                   122  Breast Cancer
# 340                          TP53 R249                   119  Breast Cancer
# 682                      TP53 Mutation                   222  Breast Cancer
# 1120                         TP53 R72P                  5146  Breast Cancer
# 1969  TP53 DNA Binding Domain Mutation                   238  Breast Cancer
# 1970                     TP53 Mutation                   222  Breast Cancer
# 3451                        TP53 C238Y                  2517  Breast Cancer
#
#         doid phenotypes    therapies therapy_interaction_type evidence_type  \
# 275   1612.0        NaN  Doxorubicin                      NaN    Predictive
# 331   1612.0        NaN          NaN                      NaN    Prognostic
# 332   1612.0        NaN          NaN                      NaN    Prognostic
# 333   1612.0        NaN          NaN                      NaN    Prognostic
# 334   1612.0        NaN          NaN                      NaN    Prognostic
# 335   1612.0        NaN          NaN                      NaN    Prognostic
# 336   1612.0        NaN          NaN                      NaN    Prognostic
# 337   1612.0        NaN          NaN                      NaN    Prognostic
# 338   1612.0        NaN          NaN                      NaN    Prognostic
# 339   1612.0        NaN          NaN                      NaN    Prognostic
# 340   1612.0        NaN  Doxorubicin                      NaN    Predictive
# 682   1612.0        NaN  Doxorubicin                      NaN    Predictive
# 1120  1612.0        NaN          NaN                      NaN  Predisposing
# 1969  1612.0        NaN    Tamoxifen                      NaN    Predictive
# 1970  1612.0        NaN    Tamoxifen                      NaN    Predictive
# 3451  1612.0        NaN          NaN                      NaN    Prognostic
#
#      evidence_direction evidence_level          significance  \
# 275            Supports              D  Sensitivity/Response
# 331            Supports              B          Poor Outcome
# 332            Supports              B          Poor Outcome
# 333            Supports              B          Poor Outcome
# 334            Supports              B          Poor Outcome
# 335            Supports              B          Poor Outcome
# 336            Supports              B          Poor Outcome
# 337            Supports              B          Poor Outcome
# 338            Supports              B          Poor Outcome
# 339            Supports              B          Poor Outcome
# 340            Supports              B  Sensitivity/Response
# 682            Supports              D  Sensitivity/Response
# 1120   Does Not Support              B        Predisposition
# 1969           Supports              B            Resistance
# 1970           Supports              C            Resistance
# 3451           Supports              E          Poor Outcome
#
#                                      evidence_statement citation_id  \
# 275   Breast tumors in a mouse model with R172H muta...    22698404
# 331   Breast cancer patients who harbor R175H mutati...    16489069
# 332   Breast cancer patients who harbor a R248Q muta...    16489069
# 333   In breast cancer patients harboring TP53 mutat...     9569050
# 334   In breast cancer patients harboring R248W muta...    16489069
# 335   In breast cancer patients harboring TP53 mutat...     9569050
# 336   Breast cancer patients who harbor R273C mutati...    16489069
# 337   In breast cancer patients harboring TP53 mutat...     9569050
# 338   Breast cancer patients who harbor R273H mutati...    16489069
# 339   In breast cancer patients harboring TP53 mutat...     9569050
# 340   Breast tumors with R175H or R249 mutations are...     9569050
# 682   In this preclinical study, MMTV-Wnt1 mammary t...    22698404
# 1120  Large meta-analysis of 5,191 breast cancer pat...    17909070
# 1969  In a study 202 breast cancer patients undergoi...    10786679
# 1970  In a study 202 breast cancer patients undergoi...    10786679
# 3451  Cys-238 was directly bound to zinc molecule. P...    11051239
#
#      source_type  asco_abstract_id              citation nct_ids  rating  \
# 275       PubMed               NaN  Jackson et al., 2012     NaN     3.0
# 331       PubMed               NaN  Olivier et al., 2006     NaN     3.0
# 332       PubMed               NaN  Olivier et al., 2006     NaN     3.0
# 333       PubMed               NaN    Berns et al., 1998     NaN     3.0
# 334       PubMed               NaN  Olivier et al., 2006     NaN     3.0
# 335       PubMed               NaN    Berns et al., 1998     NaN     3.0
# 336       PubMed               NaN  Olivier et al., 2006     NaN     3.0
# 337       PubMed               NaN    Berns et al., 1998     NaN     3.0
# 338       PubMed               NaN  Olivier et al., 2006     NaN     3.0
# 339       PubMed               NaN    Berns et al., 1998     NaN     3.0
# 340       PubMed               NaN    Berns et al., 1998     NaN     3.0
# 682       PubMed               NaN  Jackson et al., 2012     NaN     4.0
# 1120      PubMed               NaN  Schmidt et al., 2007     NaN     4.0
# 1969      PubMed               NaN    Berns et al., 2000     NaN     3.0
# 1970      PubMed               NaN    Berns et al., 2000     NaN     1.0
# 3451      PubMed               NaN   Alsner et al., 2000     NaN     3.0
#
#      evidence_status  evidence_id   variant_origin         last_review_date  \
# 275         accepted          319          Somatic  2023-01-09 21:46:28 UTC
# 331         accepted          389          Somatic  2023-01-09 21:46:28 UTC
# 332         accepted          390          Somatic  2023-01-09 21:46:28 UTC
# 333         accepted          391          Somatic  2023-01-09 21:46:28 UTC
# 334         accepted          392          Somatic  2023-01-09 21:46:28 UTC
# 335         accepted          393          Somatic  2025-12-16 09:25:48 UTC
# 336         accepted          395          Somatic  2023-01-09 21:46:28 UTC
# 337         accepted          396          Somatic  2023-01-09 21:46:28 UTC
# 338         accepted          397          Somatic  2023-01-09 21:46:28 UTC
# 339         accepted          398          Somatic  2023-01-09 21:46:28 UTC
# 340         accepted          399          Somatic  2025-12-02 14:02:14 UTC
# 682         accepted          851          Somatic  2023-01-09 21:46:30 UTC
# 1120        accepted         1302  Common Germline  2024-06-11 18:35:22 UTC
# 1969        accepted         2783          Somatic  2023-01-09 21:46:30 UTC
# 1970        accepted         2784          Somatic  2023-01-09 21:46:30 UTC
# 3451        accepted         7173          Somatic  2023-09-27 15:51:59 UTC
#
#                                  evidence_civic_url  \
# 275    https://civicdb.org/links/evidence_items/319
# 331    https://civicdb.org/links/evidence_items/389
# 332    https://civicdb.org/links/evidence_items/390
# 333    https://civicdb.org/links/evidence_items/391
# 334    https://civicdb.org/links/evidence_items/392
# 335    https://civicdb.org/links/evidence_items/393
# 336    https://civicdb.org/links/evidence_items/395
# 337    https://civicdb.org/links/evidence_items/396
# 338    https://civicdb.org/links/evidence_items/397
# 339    https://civicdb.org/links/evidence_items/398
# 340    https://civicdb.org/links/evidence_items/399
# 682    https://civicdb.org/links/evidence_items/851
# 1120  https://civicdb.org/links/evidence_items/1302
# 1969  https://civicdb.org/links/evidence_items/2783
# 1970  https://civicdb.org/links/evidence_items/2784
# 3451  https://civicdb.org/links/evidence_items/7173
#
#                             molecular_profile_civic_url  is_flagged
# 275    https://civicdb.org/links/molecular_profiles/116       False
# 331    https://civicdb.org/links/molecular_profiles/116       False
# 332    https://civicdb.org/links/molecular_profiles/117       False
# 333    https://civicdb.org/links/molecular_profiles/117       False
# 334    https://civicdb.org/links/molecular_profiles/118       False
# 335    https://civicdb.org/links/molecular_profiles/222       False
# 336    https://civicdb.org/links/molecular_profiles/121       False
# 337    https://civicdb.org/links/molecular_profiles/121       False
# 338    https://civicdb.org/links/molecular_profiles/122       False
# 339    https://civicdb.org/links/molecular_profiles/122       False
# 340    https://civicdb.org/links/molecular_profiles/119        True
# 682    https://civicdb.org/links/molecular_profiles/222       False
# 1120  https://civicdb.org/links/molecular_profiles/5146       False
# 1969   https://civicdb.org/links/molecular_profiles/238       False
# 1970   https://civicdb.org/links/molecular_profiles/222       False
# 3451  https://civicdb.org/links/molecular_profiles/2517       False
